# %% [markdown]
# # Introduction
#
# Emerging infectious diseases of zoonotic origin continue to threaten global health security, with over 60% of emerging human pathogens originating in animals. The COVID-19 pandemic, caused by a zoonotic betacoronavirus, emphasized the importance of understanding viral reservoirs in wildlife. Bats have been extensively studied as natural hosts of many zoonotic viruses, including several coronaviruses, but the role of rodents as viral reservoirs remains comparatively underexplored. This is despite their ecological ubiquity, vast species richness, and close association with human environments.
#
# Rodents (order Rodentia) comprise over 2,200 species and represent the most speciose mammalian order. Their wide geographic distribution, adaptability to urban environments, and potential for high-density populations make them prime candidates for facilitating spillover events. Several major viral pathogens with significant human health impacts have emerged from rodent hosts, including hantaviruses, arenaviruses, and most recently, mpox virus, which has been linked to African rodent species.
#
# Hantaviruses, carried by murid rodents, have caused multiple outbreaks of hantavirus pulmonary syndrome (HPS) in the Americas and hemorrhagic fever with renal syndrome (HFRS) in Eurasia. In particular, the Andes virus, endemic to South America, is of high concern due to its rare but documented capacity for person-to-person transmission. This distinguishes it from most other hantaviruses and raises significant concerns about its pandemic potential. Andes virus is primarily carried by *Oligoryzomys longicaudatus*, a rodent widely distributed across Argentina and Chile. Arenaviruses, another group of rodent-borne viruses, include several species responsible for severe hemorrhagic fevers. The Junin virus, endemic to Argentina, causes Argentine hemorrhagic fever (AHF) and is carried by *Calomys musculinus*. Historically associated with agricultural outbreaks, Junin virus infection has a high case-fatality rate if untreated, though a live attenuated vaccine (Candid #1) has been used with success. Its presence in a commonly encountered rodent in rural areas highlights the persistent risk posed by zoonotic viruses endemic to agricultural interfaces.
#
# The recent reemergence of mpox (formerly monkeypox), a poxvirus that is believed to have originated in African rodents, has also renewed interest in rodent reservoirs. Though initially considered a rare zoonosis with limited human-to-human spread, mpox has evolved in ways that allow more sustained transmission, and wild rodents remain a suspected reservoir facilitating its maintenance in endemic regions.
#
# Despite this pattern of rodent-associated viral emergence, coronaviruses found in rodents have received relatively little attention until recently. Within the genus *Betacoronavirus*, the subgenus *Embecovirus* contains several human coronaviruses (e.g., OC43, HKU1) that likely originated from rodents or ungulates. Rodent-associated *Embecoviruses* have been detected globally, but their diversity, evolutionary history, and zoonotic potential are still poorly understood.
#
# Here, we report the discovery and phylogenetic characterization of two novel *Embecovirus*-like coronaviruses identified in *Peromyscus leucopus*, a widespread North American rodent species known for its ecological overlap with humans and its role as a reservoir for multiple tick-borne pathogens. Using metagenomic sequencing and genome-resolved phylogenetics, we demonstrate that these viruses form a deeply divergent lineage within the *Embecovirus* subgenus. Our results expand the known diversity of rodent-borne coronaviruses and support the growing consensus that rodents play a critical role in coronavirus evolution and emergence.
#
# This work underscores the importance of sustained viral surveillance in rodent populations,  including those found in dense urban environments where humans and wildlife coexist in close proximity. As anthropogenic pressure continues to alter ecosystems and increase contact between humans and wildlife, identifying and characterizing the viral diversity harbored by rodents will be essential to anticipate and prevent future zoonotic spillover events.

# %% [markdown]
# # Methods

# %% [markdown]
# ## 1. Sample Collection
#
# ~~ Laura Needs to write this section ~~

# %% [markdown]
# ## 2. Pancoronavirus screening and sequencing
# Total RNA was obtained from tissues, feces, and swabs using the MagMax mirVana Total RNA isolation kit (Thermo Fisher Scientific) using the KingFisher Apex Purification System (Thermo Fisher Scientific). Prior to RNA extraction between 20 to 40 mg of sample was disrupted using the Bead Ruptor Elite (OMNI International) and 800 ul of lysis buffer. For the disruption, MagMAX Microbiome Bead Tubes were used for feces or rectal swabs and 500mg of ~2.5mm Zirconia/Silica beads (Biospec Products) were used for tissues and saliva and nasal swabs. The obtained RNA was reverse transcribed using the SuperScript VILO Master Mix (Thermo Fisher Scientific). CoV RNA was detected using a pancoronavirus nested PCR with primers targeting the conserved RdRp gene of CoVs as previously published (Watanabe et al., 2010) and using the Platinum II Taq Hot-Start DNA Polymerase (Thermo Fisher Scientific). After PCR, samples were run in a 1% agarose gel stained with GelRed (Biotium) and visualized in a Gel Doc XR System (Biorad).
#
# Pan-CoV positive samples were sequenced via nanopore (PromethION, Oxford Nanopore) using the [ARTIC](https://www.protocols.io/view/artic-sars-cov-2-sequencing-protocol-v4-lsk114-bp2l6n26rgqe/v4) amplification protocol. Amplicons were barcoded (SQK-RBK-114.96) and sequenced overnight.

# %% [markdown]
# ## 3. Genome Assembly and Phylogenetic Analysis
#
# The reads generated by nanopore were basecalled using the "Super High Accuracy Basecalling" option in MinKNOW (Oxford Nanopore) and the resulting reads were assembled via ....... (ximena please replace this with the method you used for assembly).
#
# To investigate the evolutionary relationships of the newly identified rodent coronaviruses, we performed a phylogenetic analysis based on the RNA-dependent RNA polymerase (RdRp) region encoded by the NSP12 gene. Viral genomes for the two positive samples (SM009RE and SM004RE) were aligned against related betacoronaviruses (Table 1) and annotated using the NSP12 coordinates from Mouse Hepatitis Virus A59 (NC_048217). Nucleotide sequences corresponding to the NSP12 region were extracted from each genome in Geneious (Dotmatics) and aligned using Clustal Omega.
#
# Whole-genome nucleotide sequences of 24 coronaviruses were compiled and aligned to reconstruct their evolutionary relationships. Each genome was renamed using its GenBank accession number to ensure consistent downstream handling. The sequences were aligned using MAFFT v7.505 with the --auto option for automatic strategy selection and default gap penalties. The resulting multiple sequence alignment contained 34,596 positions. Phylogenetic inference was performed using IQ-TREE v2.2.6 under the GTR+G substitution model, which was selected automatically based on model testing. Ultrafast bootstrap approximation with 1000 replicates (-B 1000) was conducted to assess node support. The resulting tree was rooted using the outgroup method and exported in Newick format as a .treefile.

# %% [markdown]
# ### Table 1: Betacoronaviruses included in Phylogenetic Analysis
#
# | Accession Number | Virus Name                         |
# |------------------|------------------------------------|
# | NC_012936.1      | Rat CoV Parker                     |
# | NC_026011.1      | BCoV HKU24-R05005I                 |
# | NC_017083.1      | Rabbit coronavirus HKU14           |
# | NC_003045.1      | Bovine Coronavirus ENT             |
# | OR468100.1       | Equine Coronavirus FL2020-CUh4     |
# | KX344031         | HCoV OC43 isolate LRTI_238         |
# | NC_006213.1      | Human Coronavirus OC43 ATCC VR-759 |
# | KY994645.1       | PHEV JL/2008                       |
# | NC_006577.2      | HCoV HKU1                          |
# | NC_048217        | MHV strain A59                     |
# | FJ647224         | Murine coronavirus MHV-3           |
# | MT820625         | Lucheng Rn rat CoV isolate Lijiang |
# | KX964649         | AcCoV-JC34 Chevriers field mouse   |
# | KF294372         | Longquan Rl rat CoV Longquan-708   |
# | KF294370         | Longquan Rl rat CoV Longquan-189   |
# | KF294371         | Longquan Rl rat CoV Longquan-370   |
# | KF294357         | Longquan Aa mouse CoV Longquan-343 |
# | OR735434         | PCoV Yale-446                      |
# | OR735433         | PCoV Yale-445                      |
# | OR613113         | PCoV Yale-225                      |
# | OR735432         | PCoV Yale-219                      |
# | MW802581         | BCoV 1 rat GCCDC3                  |
# | MW773844         | BCoV 1 rat GCCDC4                  |

# %% [markdown]
# # Results

# %% [markdown]
# ## 1. Geographic Distribution of Samples

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geodatasets

# Set CRS to EPSG:3857
crs = 'EPSG:3857'

# Load Peromyscus range and reproject
peromyscus = gpd.read_file("Peromyscus_leucopus/data_0.shp").to_crs(crs)

# Load Natural Earth land layer
land_path = geodatasets.get_path("naturalearth.land")
land = gpd.read_file(land_path).to_crs(crs)

# Define padded bounds of the Peromyscus range
minx, miny, maxx, maxy = peromyscus.total_bounds
dx, dy = maxx - minx, maxy - miny
pad = 0.1  # 10% padding
xlim = (minx - pad * dx, maxx + pad * dx)
ylim = (miny - pad * dy, maxy + pad * dy)

# Plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plot land base
land.plot(ax=ax, color="#e0e0e0", edgecolor="none")

# Plot Peromyscus range
peromyscus.plot(
    ax=ax,
    color="forestgreen",
    edgecolor="black",
    linewidth=0.5,
    alpha=0.2
)

# Zoom to padded range
ax.set_xlim(xlim)
ax.set_ylim(ylim)

# Title and cleanup
ax.axis("off")

# Save
plt.savefig("peromyscus_zoomed_map.png", dpi=300, bbox_inches="tight", pad_inches=0)
plt.show()

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import geodatasets

# Load and prep your CSVs
df_ct = pd.read_csv("dat_pancov_share.csv").dropna(subset=["lat", "lon"])
df_ct["positive"] = df_ct["PanCov_Gel_Result_Final"].str.lower().str.startswith("positive")
gdf_ct = gpd.GeoDataFrame(df_ct, geometry=gpd.points_from_xy(df_ct["lon"], df_ct["lat"]), crs="EPSG:4326").to_crs("EPSG:2857")

df_nyc = pd.read_csv("data_pancov_nyc.csv").dropna(subset=["lat", "long"])
df_nyc["positive"] = df_nyc["PanCov_Gel_Result_Final"].str.lower().str.startswith("pos")
gdf_nyc = gpd.GeoDataFrame(df_nyc, geometry=gpd.points_from_xy(df_nyc["long"], df_nyc["lat"]), crs="EPSG:4326").to_crs("EPSG:2857")

gdf_all = pd.concat([gdf_ct, gdf_nyc])

# Load Natural Earth land
land_path = geodatasets.get_path("naturalearth.land")
land = gpd.read_file("usa.shp").to_crs("EPSG:2857")

# Plot
fig, ax = plt.subplots(figsize=(10, 8))
land.plot(ax=ax, color="#e0e0e0", edgecolor="none")

gdf_all[~gdf_all["positive"]].plot(ax=ax, color="gray", markersize=15, label="Negative", alpha=0.7)
gdf_all[gdf_all["positive"]].plot(ax=ax, color="red", markersize=25, label="Positive", alpha=0.9)

buffer = 5000
minx, miny, maxx, maxy = gdf_all.total_bounds
ax.set_xlim(minx - buffer, maxx + buffer)
ax.set_ylim(miny - buffer, maxy + buffer)

ax.axis("off")
ax.legend()
plt.tight_layout()
plt.savefig("sampling_map.png", dpi=300, bbox_inches="tight", pad_inches=0)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load both images
img1 = mpimg.imread("peromyscus_zoomed_map.png")
img2 = mpimg.imread("sampling_map.png")

# Create the figure
fig, axes = plt.subplots(1, 2, figsize=(14, 7))

# Display images
axes[0].imshow(img1)
axes[0].axis("off")
axes[0].set_title("A. Range of Peromyscus leucopus", fontsize=12)

axes[1].imshow(img2)
axes[1].axis("off")
axes[1].set_title("B. Sampling Locations and PCoV Detection", fontsize=12)

# Optional overall figure title
fig.suptitle("Figure 1: Geographic Context of Sampling and Host Range", fontsize=18, y=0.98)

plt.tight_layout()
plt.subplots_adjust(top=0.90)  # allows space for the suptitle
plt.savefig("peromyscus_and_sampling_panels.png", dpi=300)
plt.show()

# %% [markdown]
# ## 2. Phylogenetic Analysis of Rodent Coronaviruses

# %% [markdown]
# ![image.png](attachment:ec747b18-fe6c-4d9f-bf7f-635bcc7646a9.png)

# %% [markdown]
# ## 3. Computational Assessment of Receptor Binding for Peromyscus Coronaviruses
#
# ~Alivia's Section~~

# %% [markdown]
# ## 4. Prediction of the ability to infect humans

# %% [markdown]
# ## 5. Selection Pressure Analysis

# %% [markdown]
# ## 6. Recombination Detection

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the cleaned CSV file
df = pd.read_csv("recombinations2.csv")

# Convert recombinant breakpoint columns to numeric kilobases
df['Begin_kb'] = pd.to_numeric(df['Begin (Recombinant)'], errors='coerce') / 1000
df['End_kb'] = pd.to_numeric(df['End (Recombinant)'], errors='coerce') / 1000

# Extract accessions from recombinant sequence field
df['Recombinant'] = df[' Recombinant Sequence(s)'].str.extract(r'([A-Z0-9_.]+)')

# Manually map accession IDs to descriptive virus labels
accession_to_label = {
    "KF294372": "Longquan-708 | Niviventer confucianus",
    "OR468100": "FL2020-CUh4 | Equus ferus",
    "OR735432.1": "Yale-219 | Peromyscus leucopus",
    "NC_006213": "OC43 | Homo sapiens",
    "MW773844": "GCCDC4 | Rattus norvegicus",
    "KF294370": "Longquan-189 | Rattus tanezumi",
    "NC_012936": "Rat Parker",
    "SM009": "SM009 | Peromyscus leucopus",
    "OR735433": "Yale-445 | Peromyscus leucopus",
    "NC_017083": "HKU14 | Homo sapiens",
    "KY994645": "JL/2008 | Sus scorfa",
    "MT820625": "Lijiang-170 | Apodemus chevrieri",
    "NC_006577": "HKU1 | Homo sapiens",
    "FJ647224": "MHV-3 | Mus musculus",
    "NC_048217": "A59 | Mus musculus",
    "NC_026011": "HKU24-R05005I | Homo sapiens",
    "MW802581": "GCCDC3 | Rattus norvegicus",
    "OR735434": "Yale-446 | Peromyscus leucopus",
    "KF294371": "Longquan-370 | Rattus losea",
}

# Apply label mapping
df['Recombinant Label'] = df['Recombinant'].map(accession_to_label)

# Drop any rows without proper mapping or breakpoints
df = df.dropna(subset=['Begin_kb', 'End_kb', 'Recombinant Label'])

# Set up unique Y positions for each recombinant label
labels = df['Recombinant Label'].unique()
label_to_y = {label: i for i, label in enumerate(sorted(labels))}

# Plot
fig, ax = plt.subplots(figsize=(12, len(labels) * 0.4))

for _, row in df.iterrows():
    y = label_to_y[row['Recombinant Label']]
    ax.plot([row['Begin_kb'], row['End_kb']], [y, y], lw=6, color='crimson')

# Set axis labels and ticks
ax.set_yticks(list(label_to_y.values()))
ax.set_yticklabels(list(label_to_y.keys()))
ax.set_xlabel("Genomic Position (kb)")
ax.set_title("Mapped Recombination Events by Recombinant Sequence")

plt.tight_layout()
plt.show()

# %% [markdown]
# "While SM009 was flagged by RDP as containing extensive recombination across nearly its entire genome, this pattern is inconsistent with manual inspection of the alignment and its near-identical sequence to five other Peromyscus-derived genomes. We therefore suspect these signals reflect false positives driven by minor sequence differences between highly similar strains."

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# Load CSV
df = pd.read_csv("recombinations2.csv")

# Convert breakpoint positions to kilobases
df['Begin_kb'] = pd.to_numeric(df['Begin (Recombinant)'], errors='coerce') / 1000
df['End_kb'] = pd.to_numeric(df['End (Recombinant)'], errors='coerce') / 1000

# Extract recombinant ID and label
df['Recombinant'] = df[' Recombinant Sequence(s)'].str.extract(r'([A-Z0-9_.]+)')
accession_to_label = {
    "KF294372": "Longquan-708 | Niviventer confucianus",
    "OR468100": "FL2020-CUh4 | Equus ferus",
    "OR735432.1": "Yale-219 | Peromyscus leucopus",
    "NC_006213": "OC43 | Homo sapiens",
    "MW773844": "GCCDC4 | Rattus norvegicus",
    "KF294370": "Longquan-189 | Rattus tanezumi",
    "NC_012936": "Rat Parker",
    "SM009": "Peromyscus leucopus",
    "OR735433": "Yale-445 | Peromyscus leucopus",
    "NC_017083": "HKU14 | Homo sapiens",
    "KY994645": "JL/2008",
    "MT820625": "Lijiang-170 | Apodemus chevrieri",
    "NC_006577": "HKU1 | Homo sapiens",
    "FJ647224": "MHV-3 | Mus musculus",
    "NC_048217": "A59 | Mus musculus",
    "NC_026011": "HKU24-R05005I | Homo sapiens",
    "MW802581": "GCCDC3 | Rattus norvegicus",
    "OR735434": "Yale-446 | Peromyscus leucopus",
    "KF294371": "Longquan-370 | Rattus losea",
}
df['Recombinant Label'] = df['Recombinant'].map(accession_to_label)

# Extract accession from major parent (as origin of recombinant segment)
df['Parent_Accession'] = df[' Major Parental Sequence(s)'].str.extract(r'([A-Z0-9_.]+)')

# Map each parent accession to a species category
accession_to_species = {
    "FJ647224": "Mus musculus",
    "NC_048217": "Mus musculus",
    "NC_006213": "Homo sapiens",
    "NC_017083": "Homo sapiens",
    "NC_006577": "Homo sapiens",
    "NC_026011": "Homo sapiens",
    "MW773844": "Rattus norvegicus",
    "MW802581": "Rattus norvegicus",
    "KF294370": "Rattus tanezumi",
    "KF294371": "Rattus losea",
    "KF294372": "Niviventer confucianus",
    "NC_012936": "Rat Parker",
    "OR735432.1": "Peromyscus leucopus",
    "OR735433": "Peromyscus leucopus",
    "SM009": "Peromyscus leucopus",
    "KY994645": "JL/2008",
    "MT820625": "Apodemus chevrieri",
    "OR468100": "Equus ferus"
}

# Choose your own custom colors for each species
species_to_color = {
    "Mus musculus": "skyblue",
    "Homo sapiens": "orange",
    "Rattus norvegicus": "green",
    "Rattus tanezumi": "lime",
    "Rattus losea": "darkgreen",
    "Niviventer confucianus": "purple",
    "Rat Parker": "brown",
    "Peromyscus leucopus": "crimson",
    "JL/2008": "gold",
    "Apodemus chevrieri": "teal",
    "Equus ferus": "black"
}

df['Parent Species'] = df['Parent_Accession'].map(accession_to_species)
df['Color'] = df['Parent Species'].map(species_to_color)

# Drop any rows missing critical info
df = df.dropna(subset=['Begin_kb', 'End_kb', 'Recombinant Label', 'Color'])

# Assign Y positions for recombinants
labels = df['Recombinant Label'].unique()
label_to_y = {label: i for i, label in enumerate(sorted(labels))}

# Plot
fig, ax = plt.subplots(figsize=(12, len(labels) * 0.4))

for _, row in df.iterrows():
    y = label_to_y[row['Recombinant Label']]
    ax.plot([row['Begin_kb'], row['End_kb']], [y, y], lw=6, color=row['Color'])

# Axis setup
ax.set_yticks(list(label_to_y.values()))
ax.set_yticklabels(list(label_to_y.keys()))
ax.set_xlabel("Genomic Position (kb)")
ax.set_title("Recombination Segments Colored by Parental Species")

# Create custom legend
legend_elements = [Patch(facecolor=color, label=species) for species, color in species_to_color.items()]
ax.legend(handles=legend_elements, title="Recombinant Origin", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Clean detection columns
methods = [' RDP', ' GENECONV', ' Bootscan', ' Maxchi', ' Chimaera', ' SiSscan', ' 3Seq']
for col in methods:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    
# -log10 transformation
support_df = df.copy()
support_df['Recombinant'] = support_df[' Recombinant Sequence(s)'].str.extract(r'(\^?[A-Z0-9_.]+)')
support_df[methods] = support_df[methods].apply(lambda x: -np.log10(x))

# Clip and sort
support_df[methods] = support_df[methods].clip(upper=50)
support_df['mean_support'] = support_df[methods].mean(axis=1)
sorted_df = support_df.sort_values(by='mean_support', ascending=False)

# Plot heatmap
plt.figure(figsize=(12, max(6, 0.4 * len(sorted_df))))
sns.heatmap(
    sorted_df[methods],
    cmap='viridis',
    linewidths=0.5,
    linecolor='white',
    cbar_kws={'label': '-log10(p-value)'},
    yticklabels=sorted_df['Recombinant']
)
plt.title("Support for Recombination Events Across Detection Methods")
plt.tight_layout()
plt.show()
